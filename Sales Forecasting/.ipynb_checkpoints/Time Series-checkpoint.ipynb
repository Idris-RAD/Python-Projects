# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
import warnings
import numpy as np

warnings.filterwarnings("ignore")
sns.set()
# %matplotlib inline

# %%
df = pd.read_csv('train.csv')

# %%
def describing(df):
        print('*************** \n Information : \n***')
        print(df.info())
        print('*************** \n Description : \n ***')
        print(df.describe(include='all'))
        print('*************** \n Head : \n ***')
        print(df.head())

def tellnas(df):
    print('Percentage of NaNs in each column : ')
    return round((df.isna().sum())/df.shape[1],2)*100

# %%
def distplots(df):
    
    colorlist = ['red','gold','orange','limegreen','seagreen','darkcyan','blue','darkorchid','hotpink','darkmagenta']
    n=len(df.columns.tolist())

    if n %2 == 0:
        nr = int(n/2)
    else:
        nr = int((n+1)/2)
        
    titles = df.columns.tolist()

    fig, axes = plt.subplots(nrows=nr, ncols=2, figsize = (20,12))
    
    for ax, tit,i in zip(axes.flat, titles, range(0,n)):
        sns.distplot(df.iloc[:,i], ax=ax, color=colorlist[i])
        ax.set(title=tit)
        ax.set_xlabel('')
        ax.title.set_size(18)
    plt.tight_layout()
    
    fig.suptitle('Distributions',y=1.03,  fontsize=22)
    return

# %% [markdown]
# # Exploratory analysis

# %%
describing(df)
# Out:
# ***************
#  Information :
# ***
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 913000 entries, 0 to 912999
# Data columns (total 4 columns):
# date     913000 non-null object
# store    913000 non-null int64
# item     913000 non-null int64
# sales    913000 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 27.9+ MB
# None
# ***************
#  Description :
#  ***
#               date          store           item          sales
# count       913000  913000.000000  913000.000000  913000.000000
# unique        1826            NaN            NaN            NaN
# top     2015-08-25            NaN            NaN            NaN
# freq           500            NaN            NaN            NaN
# mean           NaN       5.500000      25.500000      52.250287
# std            NaN       2.872283      14.430878      28.801144
# min            NaN       1.000000       1.000000       0.000000
# 25%            NaN       3.000000      13.000000      30.000000
# ...

# %%
tellnas(df)
# Out:
# Percentage of NaNs in each column :
# date     0.0
# store    0.0
# item     0.0
# sales    0.0
# dtype: float64

# %%
distplots(df[['store', 'item','sales']])

# %%
print(df.item.nunique())
print(df.store.nunique())
# 50 different items ,10 different stores
# Out:
# 50
# 10

# %%
# My computer seems very slow when processing the whole dataset.
# To make analysis faster, I'm going to keep only half of the items. 

df=df[df['item']<26]

# %%
# For the next plot, I will look at data in store NB 1, with the 5 first articles.
dfplot = df[df['store']==1]
dfplot = dfplot[dfplot['item']<6]

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.lineplot(x=dfplot['date'], y=dfplot['sales'], hue=dfplot['item'])
plt.xlim('2013-01-01', '2017-12-31')
plt.xticks(rotation=45)
ax.xaxis.set_major_locator(plt.MaxNLocator(10))
plt.title('Product sales for 5 items over 5 years in store nb 1', fontsize=20)
plt.show()

# We can easily see some seasonality going on, with product demand raising during the summer.
# This pattern seems to repeat each year, with an upward trend for demand overall.

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.scatterplot(x=dfplot['date'], y=dfplot['sales'][dfplot['item']==1])

plt.xlim('2013-01-01', '2017-12-31')

ax.xaxis.set_major_locator(plt.MaxNLocator(10))

plt.xticks(rotation=45)
plt.title('Product demand for item 1')
plt.show()

# %% [markdown]
# ## Creating columns
#
# The dataset only has 4 columns to start with. We can create some additional data by using the date information.

# %%
df.date = pd.to_datetime(df.date, format='%Y-%m-%d')

# %%
df.head()
# Out:
#         date  store  item  sales
# 0 2013-01-01      1     1     13
# 1 2013-01-02      1     1     11
# 2 2013-01-03      1     1     14
# 3 2013-01-04      1     1     13
# 4 2013-01-05      1     1     10

# %%
df['year']=df['date'].dt.year
df['month']=df['date'].dt.month
df['day']= df['date'].dt.day_name()
df['week']=df['date'].dt.week
df['dow']=df['date'].dt.dayofweek

# %%
df.head()
# Out:
#         date  store  item  sales  year  month        day  week  dow
# 0 2013-01-01      1     1     13  2013      1    Tuesday     1    1
# 1 2013-01-02      1     1     11  2013      1  Wednesday     1    2
# 2 2013-01-03      1     1     14  2013      1   Thursday     1    3
# 3 2013-01-04      1     1     13  2013      1     Friday     1    4
# 4 2013-01-05      1     1     10  2013      1   Saturday     1    5

# %% [markdown]
# ## Some visualizing

# %%
monthlysales = df.pivot_table(values=['sales'], index=['year', 'month'],aggfunc=sum)

# %%
ax = monthlysales.plot(figsize=(10,6), color='darkcyan', lw=3)

ax.set_xticks(range(len(monthlysales)))
ax.set_xticklabels(["%s-%02d" % item for item in monthlysales.index.tolist()[::4]], rotation=90)
ax.tick_params(axis='x', rotation=45)
ax.xaxis.set_major_locator(plt.MaxNLocator(15))
plt.legend(fontsize=14, fancybox=True, shadow=True)
plt.title('Total monthly sales over 5 years', fontsize=20)
plt.show()

# %%
monthlysalesy = df.pivot_table(values=['sales'], index=['month'], columns=['year'],aggfunc=sum)

# %%
monthlysalesy.head()
# Out:
#         sales
# year     2013    2014    2015    2016    2017
# month
# 1      239142  276610  289895  317389  324516
# 2      242454  278291  290096  323700  326823
# 3      325111  370502  384441  416183  432191
# 4      358945  415114  433998  474910  494248
# 5      401354  464386  488073  520297  536043

# %%
ax = monthlysalesy.plot(figsize=(10,6))
plt.legend(fontsize=14, fancybox=True, shadow=True)
plt.title('Total monthly sales over 5 years', fontsize=20)
plt.show()

# %% [markdown]
# ### Items and stores

# %%
storesales = df.pivot_table(values=['sales'], index=['store'],aggfunc=sum)
storesales = storesales.reset_index()
storesales['storenb']=[f'Store nb {i}' for i in storesales.store]
storesales
# Out:
#    store    sales      storenb
# 0      1  2271353   Store nb 1
# 1      2  3218156   Store nb 2
# 2      3  2859133   Store nb 3
# 3      4  2637907   Store nb 4
# 4      5  1908957   Store nb 5
# 5      6  1907792   Store nb 6
# 6      7  1746981   Store nb 7
# 7      8  3080446   Store nb 8
# 8      9  2642752   Store nb 9
# 9     10  2818250  Store nb 10

# %%
import squarify
import matplotlib

# %%
norm = matplotlib.colors.Normalize(vmin=min(storesales.sales), vmax=max(storesales.sales))
colors = [matplotlib.cm.jet(norm(value)) for value in storesales.sales]

#Create our plot and resize it.
fig = plt.gcf()
ax = fig.add_subplot()
fig.set_size_inches(10, 10)
plt.rc('font', size=14)
#Use squarify to plot our data, label it and add colours. We add an alpha layer to ensure black labels show through
squarify.plot(label=storesales.storenb,sizes=storesales.sales, color = colors, alpha=.6)
plt.title("Stores by total sales",fontsize=23,fontweight="bold")

#Remove our axes and display the plot
plt.axis('off')
plt.show()

# %%
storesales.sort_values(by=['sales'], ascending=False)
#The top selling store is store number 2. Let's focus on this one concerning products.
# Out:
#    store    sales      storenb
# 1      2  3218156   Store nb 2
# 7      8  3080446   Store nb 8
# 2      3  2859133   Store nb 3
# 9     10  2818250  Store nb 10
# 8      9  2642752   Store nb 9
# 3      4  2637907   Store nb 4
# 0      1  2271353   Store nb 1
# 4      5  1908957   Store nb 5
# 5      6  1907792   Store nb 6
# 6      7  1746981   Store nb 7

# %%
store2 = df[(df['store']==2)&(df['year']==2017)]  #keeping only store nb 2, in 2017
store2grouped = store2.groupby(['item']).agg('sum')
store2grouped=store2grouped['sales'].reset_index()
store2grouped['itemnumber']=[f'Item nb {i}' for i in store2grouped.item]
spiderplotdata = store2grouped.nlargest(8, 'sales')
spiderplotdata = spiderplotdata[['sales', 'itemnumber']]
spiderplotdata = spiderplotdata.set_index(['itemnumber'])
spiderplotdata = spiderplotdata.T

# %%
spiderplotdata
# Out:
# itemnumber  Item nb 15  Item nb 18  Item nb 13  Item nb 25  Item nb 22  \
# sales            46148       44776       44305       42239       42106
#
# itemnumber  Item nb 8  Item nb 10  Item nb 11
# sales           40518       38746       37045

# %%
corners = spiderplotdata.columns.tolist()
angles=np.linspace(0, 2*np.pi, len(corners), endpoint=False)

salevalues=spiderplotdata.iloc[0,:].values

salevalues=np.concatenate((salevalues,[salevalues[0]]))
angles = np.concatenate((angles,[angles[0]]))




fig=plt.figure(figsize=(20, 10))

#ax.set_rlabel_position(2)
ax = fig.add_subplot(111, polar=True)
ax.plot(angles, salevalues, 'o-', linewidth=2, color = '#20B2AA')
ax.fill(angles, salevalues, alpha=0.25,color = '#20B2AA')
ax.set_thetagrids(angles * 180/np.pi, corners)
title='Total sales for top 8 items sold in the top selling store'
plt.title(title, size=15, color='#20B2AA', y=1.1, fontsize=20)
plt.ylim(35000,47000)

ax.grid(True)

# %% [markdown]
# # Modelling
#
# What models should I use to predict product demand ?
#
# We can make out an upward trend and seasonality in our data.
#
# SARIMA seems to be a good fit as this model takes trend and seasonality into account.

# %%
dfmod = df.pivot_table(values=['sales'], index=['date'],aggfunc=sum)
# We want to aggregate all the sales, keeping only sales and date (as index).

# %%
dfmod.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06', '2013-01-07', '2013-01-08',
#                '2013-01-09', '2013-01-10',
#                ...
#                '2017-12-22', '2017-12-23', '2017-12-24', '2017-12-25',
#                '2017-12-26', '2017-12-27', '2017-12-28', '2017-12-29',
#                '2017-12-30', '2017-12-31'],
#               dtype='datetime64[ns]', name='date', length=1826, freq=None)

# %%
dfmod.asfreq('d').index  #setting frequency to days
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06', '2013-01-07', '2013-01-08',
#                '2013-01-09', '2013-01-10',
#                ...
#                '2017-12-22', '2017-12-23', '2017-12-24', '2017-12-25',
#                '2017-12-26', '2017-12-27', '2017-12-28', '2017-12-29',
#                '2017-12-30', '2017-12-31'],
#               dtype='datetime64[ns]', name='date', length=1826, freq='D')

# %%
# Seasonal decomposing to look at different components of the timeseries.

res = sm.tsa.seasonal_decompose(dfmod, model='additive', freq=365)

fig, (ax1,ax2,ax3) = plt.subplots(3,1, figsize=(15,8))
res.trend.plot(ax=ax1, title='trend', c='limegreen')
res.resid.plot(ax=ax2, title='residuals', c='cadetblue')
res.seasonal.plot(ax=ax3, title='seasonality', c='darkmagenta')
fig.suptitle('Seasonal decompose plots',y=1.03,  fontsize=18)
plt.tight_layout()

plt.show()

# We can see a clear trend over the years.
# Seasonality is also clear : over each year
# and even over each week, if we look closely.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-169-2e27408e9450> in <module>
#       4
#       5 fig, (ax1,ax2,ax3) = plt.subplots(3,1, figsize=(15,8))
# ----> 6 res.trend.plot(ax=ax1, title='trend', c='limegreen')
#       7 res.resid.plot(ax=ax2, title='residuals', c='cadetblue')
#       8 res.seasonal.plot(ax=ax3, title='seasonality', c='darkmagenta')
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2940                           fontsize=fontsize, colormap=colormap, table=table,
#    2941                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# ...

# %%
from statsmodels.tsa.stattools import acf
lac_acf = acf(dfmod['sales'], nlags=20)

plt.figure(figsize=(15,5))
plt.subplot(121)
plt.stem(lac_acf)
plt.axhline(y=0, linestyle='-', color='black')
plt.xlabel('Lag')
plt.ylabel('ACF')
plt.title('ACF over 20 lags (days)')
plt.show()

# There seems to be a repetition every 7 days (lags).

# %%
from statsmodels.tsa.stattools import acf
lac_acf = acf(dfmod['sales'], nlags=700)

plt.figure(figsize=(15,5))
plt.subplot(121)
plt.stem(lac_acf)
plt.axhline(y=0, linestyle='-', color='black')
plt.xlabel('Lag')
plt.ylabel('ACF')
plt.title('ACF over 365 lags (days)', fontsize=20)
plt.show()

# We also see a repetition in lags over 365 lags (days).

# %% [markdown]
# The autocorrelation plots show peaks every 7 days, and every 365 days.
# We can assume seasonality every year, and every week.

# %%
from pandas.plotting import lag_plot
lag_plot(dfmod)
plt.title('Lag plot', fontsize=20)

# Different lines are different years
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# Text(0.5, 1.0, 'Lag plot')

# %% [markdown]
# ### Assumptions and data preparation

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries, window = 12, cutoff = 0.01):

    #Determing rolling statistics
    rolmean = timeseries.rolling(window).mean()
    rolstd = timeseries.rolling(window).std()

    #Plot rolling statistics:
    fig = plt.figure(figsize=(12, 8))
    orig = plt.plot(timeseries, color='chocolate',label='Observed values')
    mean = plt.plot(rolmean, color='teal', label='Rolling Mean')
    std = plt.plot(rolstd, color='firebrick', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show()
    
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC', maxlag = 20 )
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput[f'Critical Value {key}'] = value
    pvalue = dftest[1]
    if pvalue < cutoff:
        print(f'p-value = {pvalue}. The series is likely stationary.')
    else:
        print(f'p-value = {pvalue}. The series is likely non-stationary.')
    
    print(dfoutput)

# %%
test_stationarity(dfmod['sales'])
# Out:
# Results of Dickey-Fuller Test:
# p-value = 0.09059682977519795. The series is likely non-stationary.
# Test Statistic                   -2.611731
# p-value                           0.090597
# #Lags Used                       20.000000
# Number of Observations Used    1805.000000
# Critical Value 1%                -3.433978
# Critical Value 5%                -2.863143
# Critical Value 10%               -2.567623
# dtype: float64

# %% [markdown]
# Clearly, the data isn't stationary. And of course it isn't, since we have a trend.

# %% [markdown]
# ### Making stationary

# %%
#Taking one difference is enough to make the TS stationary.

first_diff = dfmod.sales - dfmod.sales.shift(1)
first_diff = first_diff.dropna(inplace = False)
test_stationarity(first_diff, window = 12)
# Out:
# Results of Dickey-Fuller Test:
# p-value = 1.6978706975250164e-14. The series is likely stationary.
# Test Statistic                -8.838053e+00
# p-value                        1.697871e-14
# #Lags Used                     2.000000e+01
# Number of Observations Used    1.804000e+03
# Critical Value 1%             -3.433980e+00
# Critical Value 5%             -2.863143e+00
# Critical Value 10%            -2.567624e+00
# dtype: float64

# %% [markdown]
# ### Testing Autocorrelation and Partial Autocorrelation

# %%
import statsmodels.api as sm

fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(dfmod.sales, lags=40, ax=ax1) # 
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(dfmod.sales, lags=40, ax=ax2)# , lags=40

# %% [markdown]
# Again, we see a parameter of 7 days for seasonality.

# %% [markdown]
# ### Determining coefficients for p, d, q (resampled monthly series)

# %% [markdown]
# Working with a resampled series (y) of sales to calculate best parameters par ARIMA.
# Working with daily series is very slow for my computer. If I had worked with daily series, I could have integrated the parameter of 7 as p (nb of lags to be used in the prediction).

# %%
y = dfmod['sales'].resample('MS').mean()

# %%
def pdqseasonalpdq():
    p = d = q = range(0, 2)
    pdq = list(itertools.product(p, d, q))
    seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
    return pdq, seasonal_pdq

# print('Examples of parameter combinations for Seasonal ARIMA...')
# print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
# print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
# print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
# print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))

# %%
def bestparams(y):
    param_list=[]
    aic_list=[]
    pdq, seasonal_pdq = pdqseasonalpdq()
    for param in pdq:
        for param_seasonal in seasonal_pdq:
            mod = sm.tsa.statespace.SARIMAX(y,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)
            results = mod.fit()
            param_list.append([param,param_seasonal,results.aic])
            aic_list.append(results.aic)

    best_params=[param_list[i] for i in range(len(param_list)) if min(aic_list) == param_list[i][2]][0]
    print(f'AICs range from {min(aic_list)} to {max(aic_list)}')
    print(f'The best parameters,\nin the format [(pdq),(seasonal pdq), AIC ]\nwith the lowest AIC, are: {best_params}.')
    return

# %%
bestparams(y)
# Out:
# AICs range from 476.846259825744 to 1608.1557596694383
# The best parameters,
# in the format [(pdq),(seasonal pdq), AIC ]
# with the lowest AIC, are: [(1, 1, 0), (1, 1, 0, 12), 476.846259825744].

# %% [markdown]
# ### SARIMA
# #### Building the model

# %% [markdown]
# From running the bestparams function, we can see the best parameters for pdq are (1,1,0).
#
# Also, SARIMA doesn't require to make the data stationary beforehand, as the difference is included in the parameters.

# %%
mod = sm.tsa.statespace.SARIMAX(y,
                                order=(1, 1, 0),
                                seasonal_order=(1, 1, 0, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary())
# Out:
#                                  Statespace Model Results
# ...
# Dep. Variable:                              sales   No. Observations:                   60
# Model:             SARIMAX(1, 1, 0)x(1, 1, 0, 12)   Log Likelihood                -235.423
# Date:                            Thu, 11 Jul 2019   AIC                            476.846
# Time:                                    10:19:32   BIC                            481.425
# Sample:                                01-01-2013   HQIC                           478.408
#                                      - 12-01-2017
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.3863      0.188     -2.056      0.040      -0.755      -0.018
# ar.S.L12      -0.0889      0.127     -0.698      0.485      -0.338       0.161
# ...

# %% [markdown]
# #### Testing the model

# %%
results.plot_diagnostics(figsize=(16, 8))
plt.show()

# %%
pred = results.get_prediction(start=pd.to_datetime('2017-01-01'), dynamic=False)
pred_ci = pred.conf_int()    #confidence interval
ax = y['2013':].plot(label='Observed', color='goldenrod',linewidth=4)
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7), color='darkcyan',linewidth=3, ls='dashed')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Year', fontsize=18)
ax.set_ylabel('Nb of sales', fontsize=18)
plt.legend(fontsize=14, fancybox=True, shadow=True)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title('Total sales forecast for the next 36 months', fontsize=22)
plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = y['2017-01-01':]
sarimamse = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(sarimamse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 63936.54

# %%
print('The Root Mean Squared Error of our forecasts is {}'.format(round(np.sqrt(sarimamse), 2)))
print(f'Daily sales range from {dfmod.sales.min()} to {dfmod.sales.max()}.')
# Out:
# The Root Mean Squared Error of our forecasts is 252.86
# Daily sales range from 6103 to 23710.

# %%
pred_uc = results.get_forecast(steps=36)   #steps = next months to forecast
pred_ci = pred_uc.conf_int()  #confidence interval
ax = y.plot(label='Observed', figsize=(14, 7), color='goldenrod',linewidth=4)
pred_uc.predicted_mean.plot(ax=ax, label='Forecast', color='darkcyan',linewidth=4)
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.1)
ax.set_xlabel('Year', fontsize=18)
ax.set_ylabel('Nb of sales', fontsize=18)
plt.legend(fontsize=14, fancybox=True, shadow=True)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title('Total sales forecast for the next 36 months', fontsize=22)
plt.show()

# %%
pred_uc.predicted_mean.loc['2019-04-01']
# Out:
# 17702.843482724747

# %%
def valueprediction():
    print('You will be asked to enter the year and month you want to predict.\nPlease type carefully to avoid errors.')

    yearuser = input('Which year, from 2018 to 2020 ?')
    monthuser = input('Which month from 01 to 12 ?')

    dateuser = f'{yearuser}-{monthuser}-01'

    value1 = round(pred_uc.predicted_mean.loc[dateuser],2)
    valuelow = round(pred_ci.loc[dateuser].loc['lower sales'],2)
    valuehigh = round(pred_ci.loc[dateuser].loc['upper sales'],2)

    print(f'The sale prediction for {dateuser} is {value1}.\nThe confidence interval for this prediction ranges from {valuelow} to {valuehigh}')
    return

# %%
valueprediction()
# Out:
# You will be asked to enter the year and month you want to predict.
# Please type carefully to avoid errors.
# Which year, from 2018 to 2020 ?2020
# Which month from 01 to 12 ?04
# The sale prediction for 2020-04-01 is 18318.32.
# The confidence interval for this prediction ranges from 14995.69 to 21640.95

# %% [markdown]
# #### Sarima (non resampled data)

# %%
y2 = df[df['year']>=2015]
y2.shape
# Out:
# (274000, 9)

# %%
y2=y2[['date','sales']]

# %%
y2 = y2.groupby(['date']).agg('sum')

# %%
y2 =y2.asfreq(freq='D')

# %%
y2.index
# Out:
# DatetimeIndex(['2015-01-01', '2015-01-02', '2015-01-03', '2015-01-04',
#                '2015-01-05', '2015-01-06', '2015-01-07', '2015-01-08',
#                '2015-01-09', '2015-01-10',
#                ...
#                '2017-12-22', '2017-12-23', '2017-12-24', '2017-12-25',
#                '2017-12-26', '2017-12-27', '2017-12-28', '2017-12-29',
#                '2017-12-30', '2017-12-31'],
#               dtype='datetime64[ns]', name='date', length=1096, freq='D')

# %% [markdown]
# Choosing best parameters : lags are equal to 7, which means seasonality will be 7 days.
# ![image.png](attachment:image.png)

# %%
def pdqseasonalpdq():
    p = d = q = range(0, 2)
    pdq = list(itertools.product(p, d, q))
    seasonal_pdq = [(x[0], x[1], x[2], 7) for x in list(itertools.product(p, d, q))]
    return pdq, seasonal_pdq

# %%
bestparams(y2)
# Out:
# AICs range from 16314.549418921984 to 24179.526373796198
# The best parameters,
# in the format [(pdq),(seasonal pdq), AIC ]
# with the lowest AIC, are: [(1, 1, 1), (0, 1, 1, 7), 16314.549418921984].

# %%
mod2 = sm.tsa.statespace.SARIMAX(y2,
                                order=(1, 1, 1),
                                seasonal_order=(0, 1, 1, 7),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results2 = mod2.fit()
print(results2.summary())

## P values are better here
# Out:
#                                  Statespace Model Results
# ...
# Dep. Variable:                             sales   No. Observations:                 1096
# Model:             SARIMAX(1, 1, 1)x(0, 1, 1, 7)   Log Likelihood               -8153.275
# Date:                           Thu, 11 Jul 2019   AIC                          16314.549
# Time:                                   11:26:03   BIC                          16334.485
# Sample:                               01-01-2015   HQIC                         16322.098
#                                     - 12-31-2017
# Covariance Type:                             opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8812      0.020     44.854      0.000       0.843       0.920
# ma.L1         -0.9719      0.013    -75.966      0.000      -0.997      -0.947
# ...

# %%
results2.plot_diagnostics(figsize=(16, 8))
plt.show()

# %%
pred2 = results2.get_prediction(start=pd.to_datetime('2017-01-01'), dynamic=False)
pred_ci2 = pred2.conf_int()    #confidence interval
ax = y2['2015':].plot(label='Observed', color='goldenrod',linewidth=2)
pred2.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7), color='darkcyan',linewidth=2, ls='dashed')
ax.fill_between(pred_ci2.index,
                pred_ci2.iloc[:, 0],
                pred_ci2.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Year', fontsize=18)
ax.set_ylabel('Nb of sales', fontsize=18)
plt.legend(fontsize=14, fancybox=True, shadow=True)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title('Predictions for 1 year with daily sales', fontsize=22)
plt.show()

# %%
pred_uc2 = results2.get_forecast(steps=90)   #steps = next months to forecast
pred_ci2 = pred_uc2.conf_int()  #confidence interval
ax = y2.plot(label='Observed', figsize=(14, 7), color='goldenrod',linewidth=2)
pred_uc2.predicted_mean.plot(ax=ax, label='Forecast', color='darkcyan',linewidth=2)
ax.fill_between(pred_ci2.index,
                pred_ci2.iloc[:, 0],
                pred_ci2.iloc[:, 1], color='k', alpha=.1)
ax.set_xlabel('Year', fontsize=18)
ax.set_ylabel('Nb of sales', fontsize=18)
plt.legend(fontsize=14, fancybox=True, shadow=True)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title('Total sales forecast for the next year', fontsize=22)
plt.show()

# %% [markdown]
# This model seems to only focus on weekly trends, forgetting about monthly variations.

# %% [markdown]
# ### Prophet

# %% [markdown]
# For Prophet ,we're going to use training and testing dfs.
# The data needs to be organized in two columns, one 'ds' with dates, and one with 'y' as values to predict.

# %%
from fbprophet import Prophet
# Out:
# ERROR:fbprophet:Importing plotly failed. Interactive plots will not work.

# %%
df_prophet = dfmod.reset_index()
df_prophet.columns=['ds','y']

# %%
train, test = df_prophet[:-365], df_prophet[-365:]

# %%
#%%time
m = Prophet(yearly_seasonality=True, weekly_seasonality=True)
m.fit(train)

future = m.make_future_dataframe(periods=365)
future.tail(n=3)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#              ds
# 1823 2017-12-29
# 1824 2017-12-30
# 1825 2017-12-31

# %%
forecast = m.predict(future)
forecast.tail(n=3)
# Out:
#              ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 1823 2017-12-29  16609.456576  12384.876423  14694.636402  15851.924894
# 1824 2017-12-30  16612.607265  13279.485014  15592.065349  15851.552454
# 1825 2017-12-31  16615.757954  14183.417352  16432.014514  15851.687518
#
#        trend_upper  additive_terms  additive_terms_lower  \
# 1823  17490.820328    -3161.126353          -3161.126353
# 1824  17497.231482    -2275.385307          -2275.385307
# 1825  17506.048031    -1374.969958          -1374.969958
#
#       additive_terms_upper       weekly  weekly_lower  weekly_upper  \
# 1823          -3161.126353   750.093159    750.093159    750.093159
# 1824          -2275.385307  1631.116161   1631.116161   1631.116161
# 1825          -1374.969958  2530.669696   2530.669696   2530.669696
#
#            yearly  yearly_lower  yearly_upper  multiplicative_terms  \
# 1823 -3911.219512  -3911.219512  -3911.219512                   0.0
# ...

# %%
fig = plt.figure(figsize=(10, 6))

m.plot(forecast)
plt.title('Prophet forecast', fontsize=22)
plt.tight_layout()

# %%
fig= m.plot_components(forecast)
fig.suptitle('Prophet components', y=1.01)
plt.tight_layout()

# %% [markdown]
# #### Prophet evaluation

# %%
prophetpredictions = forecast['yhat'][-365:]

# %%
comparison = pd.DataFrame({'predicted':prophetpredictions,'observed':test['y']})

# %%
comparison.head()
# Out:
#          predicted  observed
# 1461  14089.709345     12455
# 1462   8782.475094      8292
# 1463  10536.408246      9722
# 1464  10548.981344      9710
# 1465  11386.778976     10443

# %%
comparison.columns
# Out:
# Index(['predicted', 'observed'], dtype='object')

# %%
prophetmse = ((comparison['predicted'] - comparison['observed']) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(prophetmse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 886250.62

# %%
print('The Root Mean Squared Error of our forecasts is {}'.format(round(np.sqrt(prophetmse), 2)))
print(f'Daily sales range from {dfmod.sales.min()} to {dfmod.sales.max()}.')
# Out:
# The Root Mean Squared Error of our forecasts is 941.41
# Daily sales range from 6103 to 23710.

# %% [markdown]
# # Comparing models

# %%
didx = pd.DatetimeIndex(start ='2017-01-01', freq ='D',  periods = 365)

# %%
comparison2 = comparison.set_index(didx)

# %%
comparison2.head()
# Out:
#                predicted  observed
# 2017-01-01  14089.709345     12455
# 2017-01-02   8782.475094      8292
# 2017-01-03  10536.408246      9722
# 2017-01-04  10548.981344      9710
# 2017-01-05  11386.778976     10443

# %%
comparison2 = comparison2.resample('MS').mean()

# %%
comparison2.columns=['prophet_predictions', 'observed']
comparison2['sarima_predictions']=pred.predicted_mean.values
comparison2.head()
# Out:
#             prophet_predictions      observed  sarima_predictions
# 2017-01-01         11564.017582  10468.258065        11222.440839
# 2017-02-01         12681.221260  11672.250000        11670.223424
# 2017-03-01         14654.666007  13941.645161        13810.317626
# 2017-04-01         16842.588728  16474.933333        16306.466990
# 2017-05-01         17674.257229  17291.709677        17396.003182

# %%
comparison2 = comparison2.reset_index()

# %%
comparison2.columns=['dates','prophet_predictions','observed','sarima_predictions']

# %%
comparison2.dtypes
# Out:
# dates                  datetime64[ns]
# prophet_predictions           float64
# observed                      float64
# sarima_predictions            float64
# dtype: object

# %%
comparison2['month']=comparison2['dates'].dt.month

# %%
comparison2.drop(['dates'], axis=1, inplace=True)

# %%
comparison2 = comparison2.set_index(['month'])
comparison2.head()
# Out:
#        prophet_predictions      observed  sarima_predictions
# month
# 1             11564.017582  10468.258065        11222.440839
# 2             12681.221260  11672.250000        11670.223424
# 3             14654.666007  13941.645161        13810.317626
# 4             16842.588728  16474.933333        16306.466990
# 5             17674.257229  17291.709677        17396.003182

# %%
comparison2[['prophet_predictions','observed','sarima_predictions']].plot(figsize=(14, 7), lw=3,color=['deeppink', 'darkslategrey','gold'])
plt.legend(fontsize=16, fancybox=True, shadow=True)
plt.xticks(fontsize=14)
plt.xlabel('month',fontsize=14)
plt.yticks(fontsize=14)
plt.title('Comparison of SARIMA and Prophet predictions for 2017 sales', fontsize=22)
# Out:
# Text(0.5, 1.0, 'Comparison of SARIMA and Prophet predictions for 2017 sales')

# %%
comparison2['prophet_errors']=abs(comparison2['prophet_predictions']-comparison2['observed'])
comparison2['sarima_errors']=abs(comparison2['sarima_predictions']-comparison2['observed'])

comparison2[['prophet_errors', 'sarima_errors']].plot(figsize=(14, 7),linestyle='dashed',color=['deeppink', 'gold'], lw=3)
plt.legend(fontsize=16, fancybox=True, shadow=True,loc='upper center')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('month',fontsize=14)
plt.title('Absolute value of errors for 2017 predictions', fontsize=20)
plt.show()

# %%
comparison2[['prophet_errors', 'sarima_errors']].plot.bar(figsize=(14, 10),color=['deeppink', 'gold'])
plt.legend(fontsize=16, fancybox=True, shadow=True,loc='right center')
plt.xticks(fontsize=14, rotation=0)
plt.yticks(fontsize=14)
plt.ylabel('amount of error',fontsize=14)
plt.xlabel('month',fontsize=14)
plt.title('Absolute value of errors for 2017 predictions', fontsize=20)
plt.show()
